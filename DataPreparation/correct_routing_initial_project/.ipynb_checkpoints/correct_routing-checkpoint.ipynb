# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# دادگان گم‌شده و پرت
# </font>
# </h1>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# غلامرضا علاقه شدیدی به حوزه کار با دیتا دارد و شروع به یادگیری کرده‌است. او برای تمرین بیشتری نیاز به یک مجموعه‌داده پیدا کرد و برای همین تصمیم گرفت از داده‌های تولیدشده دستگاه GPS ماشین پدرش استفاده کند. اما مشکلی به‌وجود آمد...!
# </ br>
# دستگاهی که توسط پدر غلامرضا خریداری شده‌بود، دستگاهی بود که گاهی‌اوقات داده‌هارا ثبت نمی‌کرد یا مقادیر عجیبی! ثبت می‌کرد. برای همین هم‌اکنون غلامرضا اندکی سردرگم شده‌است و از شما درخواست‌ دارد به کمک او بشتابید.
# </font>
# </p>

# %% [markdown]
# <div dir=rtl id="start" style="direction:rtl;line-height:200%;">
# <font face="vazir" size=3>
# برای آشنایی با توضیحات هر ستون نگاهی به جدول زیر بیاندازید:
# </font>
# </div>
#
# </br>
#
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <table dir=rtl align = center>
#
# <tr>
#     <th align = center><font face="vazir" size=3>نام ستون</font></th>
#     <th align = center><font face="vazir" size=3>توضیح</font></th>
# </tr>
#
# <tr>
#     <td align = center><font face="vazir" size=3>Date</font></td>
#     <td align = center><font face="vazir" size=3>تاریخ سفر</font></td>
# </tr>
#
# <tr>
#     <td align = center><font face="vazir" size=3>StartTime</font></td>
#     <td align = center><font face="vazir" size=3>ساعت ماشین سوار شدن</font></td>
# </tr
#
# <tr>
#     <td align = center><font face="vazir" size=3>DayOfWeek</font></td>
#     <td align = center><font face="vazir" size=3>نام روز در هفته</font></td>
# </tr>
#
# <tr>
#     <td align = center><font face="vazir" size=3>GoingTo</font></td>
#     <td align = center><font face="vazir" size=3>مقصد سفر پدر غلامرضا. یا به محل کار(work) و یا به خانه (home)</font></td>
# </tr>
#
# <tr>
#     <td align = center><font face="vazir" size=3>Distance</font></td>
#     <td align = center><font face="vazir" size=3>مسافت طی‌شده به کیلومتر</font></td>
# </tr>
#
# <tr>
#     <td align = center><font face="vazir" size=3>MaxSpeed</font></td>
#     <td align = center><font face="vazir" size=3>سریع ترین سرعت ثبت شده</font></td>
# </tr>
#
# <tr>
#     <td align = center><font face="vazir" size=3>AvgSpeed</font></td>
#     <td align = center><font face="vazir" size=3>میانگین سرعت برای کل سفر</font></td>
# </tr>
#
# <tr>
#     <td align = center><font face="vazir" size=3>AvgMovingSpeed</font></td>
#     <td align = center><font face="vazir" size=3>میانگین سرعت ثبت شده فقط در حین حرکت خودرو</font></td>
# </tr>
#
# <tr>
#     <td align = center><font face="vazir" size=3>FuelEconomy</font></td>
#     <td align = center><font face="vazir" size=3>تخمین تقریبی از مصرف سوخت</font></td>
# </tr>
#
# <tr>
#     <td align = center><font face="vazir" size=3>TotalTime</font></td>
#     <td align = center><font face="vazir" size=3>مدت کل سفر، به دقیقه</font></td>
# </tr>
#
# <tr>
#     <td align = center><font face="vazir" size=3>MaxSpeed</font></td>
#     <td align = center><font face="vazir" size=3>سریع ترین سرعت ثبت شده</font></td>
# </tr>
#
# <tr>
#     <td align = center><font face="vazir" size=3>MaxSpeed</font></td>
#     <td align = center><font face="vazir" size=3>سریع ترین سرعت ثبت شده</font></td>
# </tr>
#
# <tr>
#     <td align = center><font face="vazir" size=3>MovingTime</font></td>
#     <td align = center><font face="vazir" size=3>مدت زمانی که ماشین در حال حرکت است (یعنی بدون احتساب تاخیرهای ترافیکی، تصادفات، یا زمانی که ماشین ساکن است)</font></td>
# </tr>
#
# <tr>
#     <td align = center><font face="vazir" size=3>Toll</font></td>
#     <td align = center><font face="vazir" size=3>در زمان‌هایی که پدرغلامرضا دیرش شده‌است، از مسیرهایی می‌رود که مجبور به پرداخت عوارض است. هنگامی که این اتفاق بیفتد در این ستون Yes نوشته می‌شود و هنگامی‌که از مسیرهایی که عوارضی‌ ندارد سفر طی شود، مقدار No نوشته می‌شود</font></td>
# </tr>
#
# <tr>
#     <td align = center><font face="vazir" size=3>Comments</font></td>
#     <td align = center><font face="vazir" size=3>یادداشت‌های ثبت‌شده توسط پدر غلامرضا به شکلی دستی</font></td>
# </tr>
#
# </table>
# </p>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در این قسمت، کتاب‌خانه‌های مورد نیاز import می‌شود.</font>
# </p>

# %%
import numpy as np
import pandas as pd
from flaml import AutoML
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# برای شروع، داده‌ها را خوانده و نگاهی به آن‌ها می‌اندازیم:
# </font>
# </p>

# %%
# read csv file
df = pd.read_csv('travel_times.csv')
df
# Out:
#           Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0     1/6/2012     16:37     Friday    home     51.29     127.4      78.3
# 1     1/6/2012      8:20     Friday    work     51.63     130.3      81.8
# 2     1/4/2012     16:17  Wednesday    home     51.27    1207.4      82.0
# 3     1/4/2012      7:53  Wednesday    work     49.17     132.3      74.2
# 4     1/3/2012     18:57    Tuesday    home     51.15     136.2      83.4
# ..         ...       ...        ...     ...       ...       ...       ...
# 200  7/18/2011      8:09     Monday    work     54.52     125.6      49.9
# 201  7/14/2011      8:03   Thursday    work     50.90    3123.7      76.2
# 202  7/13/2011     17:08  Wednesday    home     51.96     132.6      57.5
# 203  7/12/2011     17:51    Tuesday    home     53.28     125.8      61.6
# 204  7/11/2011     16:56     Monday    home     51.73    -120.0      62.8
#
#      AvgMovingSpeed  FuelEconomy  TotalTime  MovingTime Toll Comments
# 0              84.8          NaN       39.3        36.3   No      NaN
# 1              88.9          NaN       37.9        34.9   No      NaN
# 2               NaN          NaN        NaN        35.9   No      NaN
# 3              82.9          NaN       39.8        35.6  NaN      NaN
# 4              88.1          NaN       36.8        34.8  NaN      NaN
# ..              ...          ...        ...         ...  ...      ...
# 200            82.4         7.89       65.5        39.7   No      NaN
# 201             NaN         7.89       40.1        32.1  Yes      NaN
# 202            76.7          NaN       54.2        40.6  Yes      NaN
# 203             NaN          NaN       51.9        36.5  Yes      NaN
# 204             NaN          NaN        NaN        33.6  Yes      NaN
#
# [205 rows x 13 columns]

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# با صدا زدن متد info، نگاهی کلی به دیتاست می‌اندازیم.
# </font>
# </p>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            205 non-null    object
#  1   StartTime       205 non-null    object
#  2   DayOfWeek       205 non-null    object
#  3   GoingTo         205 non-null    object
#  4   Distance        205 non-null    float64
#  5   MaxSpeed        205 non-null    float64
#  6   AvgSpeed        205 non-null    float64
#  7   AvgMovingSpeed  188 non-null    float64
#  8   FuelEconomy     186 non-null    float64
#  9   TotalTime       176 non-null    float64
#  10  MovingTime      205 non-null    float64
#  11  Toll            174 non-null    object
#  12  Comments        24 non-null     object
# dtypes: float64(7), object(6)
# memory usage: 20.9+ KB

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# همان‌طور که مشاهده می‌شود، به‌جز ستون‌های TotalTime، FuelEconomy، Toll و Comments، تمامی ستون‌ها حاوی مقادیر غیر NaN می‌باشند
#     </ br>
#     تعداد مقادیر NaN ستون Comments، بسیار بیشتر از مقادیر غیر NaN آن است. بنابراین این ستون را از دیتاست خود حذف کنید.
# </font>
# </p>

# %%
# drop comments column
df = df.drop('Comments',axis=1)
df
# Out:
#           Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0     1/6/2012     16:37     Friday    home     51.29     127.4      78.3
# 1     1/6/2012      8:20     Friday    work     51.63     130.3      81.8
# 2     1/4/2012     16:17  Wednesday    home     51.27    1207.4      82.0
# 3     1/4/2012      7:53  Wednesday    work     49.17     132.3      74.2
# 4     1/3/2012     18:57    Tuesday    home     51.15     136.2      83.4
# ..         ...       ...        ...     ...       ...       ...       ...
# 200  7/18/2011      8:09     Monday    work     54.52     125.6      49.9
# 201  7/14/2011      8:03   Thursday    work     50.90    3123.7      76.2
# 202  7/13/2011     17:08  Wednesday    home     51.96     132.6      57.5
# 203  7/12/2011     17:51    Tuesday    home     53.28     125.8      61.6
# 204  7/11/2011     16:56     Monday    home     51.73    -120.0      62.8
#
#      AvgMovingSpeed  FuelEconomy  TotalTime  MovingTime Toll
# 0              84.8          NaN       39.3        36.3   No
# 1              88.9          NaN       37.9        34.9   No
# 2               NaN          NaN        NaN        35.9   No
# 3              82.9          NaN       39.8        35.6  NaN
# 4              88.1          NaN       36.8        34.8  NaN
# ..              ...          ...        ...         ...  ...
# 200            82.4         7.89       65.5        39.7   No
# 201             NaN         7.89       40.1        32.1  Yes
# 202            76.7          NaN       54.2        40.6  Yes
# 203             NaN          NaN       51.9        36.5  Yes
# 204             NaN          NaN        NaN        33.6  Yes
#
# [205 rows x 12 columns]

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# مقادیر گم‌شده ستون‌های FuelEconomy و AvgMovingSpeed را با میانگین این ستون‌ها پر کنید. (مقادیر میانگین‌گرفته‌شده‌را تا دو رقم اعشار با تابع round، گرد کنید)
# </font>
# </p>

# %%
# fill NaN values in the AvgMovingSpeed and FuelEconomy
# to do
df['FuelEconomy'].fillna(round(df['FuelEconomy'].mean(),2),inplace=True)
df['AvgMovingSpeed'].fillna(round(df['AvgMovingSpeed'].mean(),2),inplace=True)
df
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4332\3347058384.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['FuelEconomy'].fillna(round(df['FuelEconomy'].mean(),2),inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4332\3347058384.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AvgMovingSpeed'].fillna(round(df['AvgMovingSpeed'].mean(),2),inplace=True)
#           Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0     1/6/2012     16:37     Friday    home     51.29     127.4      78.3
# 1     1/6/2012      8:20     Friday    work     51.63     130.3      81.8
# 2     1/4/2012     16:17  Wednesday    home     51.27    1207.4      82.0
# 3     1/4/2012      7:53  Wednesday    work     49.17     132.3      74.2
# 4     1/3/2012     18:57    Tuesday    home     51.15     136.2      83.4
# ..         ...       ...        ...     ...       ...       ...       ...
# 200  7/18/2011      8:09     Monday    work     54.52     125.6      49.9
# 201  7/14/2011      8:03   Thursday    work     50.90    3123.7      76.2
# 202  7/13/2011     17:08  Wednesday    home     51.96     132.6      57.5
# 203  7/12/2011     17:51    Tuesday    home     53.28     125.8      61.6
# 204  7/11/2011     16:56     Monday    home     51.73    -120.0      62.8
#
#      AvgMovingSpeed  FuelEconomy  TotalTime  MovingTime Toll
# 0             84.80         8.69       39.3        36.3   No
# 1             88.90         8.69       37.9        34.9   No
# 2             81.83         8.69        NaN        35.9   No
# 3             82.90         8.69       39.8        35.6  NaN
# 4             88.10         8.69       36.8        34.8  NaN
# ..              ...          ...        ...         ...  ...
# 200           82.40         7.89       65.5        39.7   No
# 201           81.83         7.89       40.1        32.1  Yes
# 202           76.70         8.69       54.2        40.6  Yes
# 203           81.83         8.69       51.9        36.5  Yes
# 204           81.83         8.69        NaN        33.6  Yes
#
# [205 rows x 12 columns]

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# یکی از راه‌های پرکردن مقادیر گم‌شده، پیش‌بینی آن‌ها با استفاده از مدل‌های یادگیری‌ماشین می‌باشد. برای همین منظور، چند سلول کد زیر را اجرا کنید تا مقادیر NaN ستون‌های TotalTime و Toll پیدا شود. هرچند از خودتان انتظار نداشته باشید هم‌اکنون از این کد سر در بیاورید. هنگامی که درسنامه مربوطه در ادامه دوره‌ را خواندید، دوباره به این بخش از درسنامه سر بزنید.    </font>
# </p>

# %%
automl_reg = AutoML()
x_train, x_test = df.dropna(subset=['TotalTime']), df[df.TotalTime.isna()]
y_train = df[~df.TotalTime.isna()].TotalTime
automl_reg.fit(x_train, y_train, task="regression", verbose=False)
y_pred = automl_reg.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       2 x_train, x_test = df.dropna(subset=['TotalTime']), df[df.TotalTime.isna()]
#       3 y_train = df[~df.TotalTime.isna()].TotalTime
# ----> 4 automl_reg.fit(x_train, y_train, task="regression", verbose=False)
#       5 y_pred = automl_reg.predict(x_test)
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\automl.py:1983, in AutoML.fit(self, X_train, y_train, dataframe, label, metric, task, n_jobs, log_file_name, estimator_list, time_budget, max_iter, sample, ensemble, eval_method, log_type, model_history, split_ratio, n_splits, log_training_metric, mem_thres, pred_time_limit, train_time_limit, X_val, y_val, sample_weight_val, groups_val, groups, verbose, retrain_full, split_type, learner_selector, hpo_method, starting_points, seed, n_concurrent_trials, keep_search_state, preserve_checkpoint, early_stop, force_cancel, append_log, auto_augment, min_sample_size, use_ray, use_spark, free_mem_ratio, metric_constraints, custom_hp, time_col, cv_score_agg_func, skip_transform, mlflow_logging, fit_kwargs_by_estimator, mlflow_exp_name, **fit_kwargs)
#    1981 else:
#    1982     self._training_log = None
# -> 1983     self._search()
#    1984 if self._best_estimator:
#    1985     logger.info("fit succeeded")
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\automl.py:2533, in AutoML._search(self)
#    2531     state.best_config = state.init_config[0] if state.init_config else {}
#    2532 elif self._use_ray is False and self._use_spark is False:
# -> 2533     self._search_sequential()
#    2534 else:
#    2535     self._search_parallel()
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\automl.py:2358, in AutoML._search_sequential(self)
#    2352         search_state.search_alg.searcher.set_search_properties(
#    2353             metric=None,
#    2354             mode=None,
#    2355             metric_target=self._state.best_loss,
#    2356         )
#    2357 start_run_time = time.time()
# -> 2358 analysis = tune.run(
#    2359     search_state.training_function,
#    2360     search_alg=search_state.search_alg,
#    2361     time_budget_s=time_budget_s,
#    2362     verbose=max(self.verbose - 3, 0),
#    2363     use_ray=False,
#    2364     use_spark=False,
#    2365     force_cancel=self._force_cancel,
#    2366     mlflow_exp_name=self._mlflow_exp_name,
#    2367     automl_info=(0,),  # pass automl info to tune.run
#    2368     extra_tag=self.autolog_extra_tag,
#    2369 )
#    2370 time_used = time.time() - start_run_time
#    2371 better = False
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\tune\tune.py:887, in run(evaluation_function, config, low_cost_partial_config, cat_hp_cost, metric, mode, time_budget_s, points_to_evaluate, evaluated_rewards, resource_attr, min_resource, max_resource, reduction_factor, scheduler, search_alg, verbose, local_dir, num_samples, resources_per_trial, config_constraints, metric_constraints, max_failure, use_ray, use_spark, use_incumbent_result_in_evaluation, log_file_name, lexico_objectives, force_cancel, n_concurrent_trials, mlflow_exp_name, automl_info, extra_tag, cost_attr, cost_budget, **ray_args)
#     885 result = None
#     886 with PySparkOvertimeMonitor(time_start, time_budget_s, force_cancel):
# --> 887     result = evaluation_function(trial_to_run.config)
#     888 logger.debug(f"result in tune: {trial_to_run}, {result}")
#     889 if result is not None:
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\state.py:306, in AutoMLState._compute_with_config_base(config_w_resource, state, estimator, is_report)
#     289     del config["FLAML_sample_size"]
#     290 budget = (
#     291     None
#     292     if state.time_budget < 0
#    (...)
#     297     )
#     298 )
#     300 (
#     301     trained_estimator,
#     302     val_loss,
#     303     metric_for_logging,
#     304     _,
#     305     pred_time,
# --> 306 ) = compute_estimator(
#     307     sampled_X_train,
#     308     sampled_y_train,
#     309     state.X_val,
#     310     state.y_val,
#     311     state.weight_val,
#     312     state.groups_val,
#     313     state.train_time_limit if budget is None else min(budget, state.train_time_limit or np.inf),
#     314     state.kf,
#     315     config,
#     316     state.task,
#     317     estimator,
#     318     state.eval_method,
#     319     state.metric,
#     320     state.best_loss,
#     321     state.n_jobs,
#     322     state.learner_classes.get(estimator),
#     323     state.cv_score_agg_func,
#     324     state.log_training_metric,
#     325     this_estimator_kwargs,
#     326     state.free_mem_ratio,
#     327 )
#     328 if state.retrain_final and not state.model_history:
#     329     trained_estimator.cleanup()
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\ml.py:382, in compute_estimator(X_train, y_train, X_val, y_val, weight_val, groups_val, budget, kf, config_dic, task, estimator_name, eval_method, eval_metric, best_val_loss, n_jobs, estimator_class, cv_score_agg_func, log_training_metric, fit_kwargs, free_mem_ratio)
#     364     val_loss, metric_for_logging, train_time, pred_time = get_val_loss(
#     365         config_dic,
#     366         estimator,
#    (...)
#     379         free_mem_ratio=0,
#     380     )
#     381 else:
# --> 382     val_loss, metric_for_logging, train_time, pred_time = task.evaluate_model_CV(
#     383         config_dic,
#     384         estimator,
#     385         X_train,
#     386         y_train,
#     387         budget,
#     388         kf,
#     389         eval_metric,
#     390         best_val_loss,
#     391         cv_score_agg_func,
#     392         log_training_metric=log_training_metric,
#     393         fit_kwargs=fit_kwargs,
#     394         free_mem_ratio=0,
#     395     )
#     397 if isinstance(estimator, TransformersEstimator):
#     398     del fit_kwargs["metric"], fit_kwargs["X_val"], fit_kwargs["y_val"]
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\task\generic_task.py:785, in GenericTask.evaluate_model_CV(self, config, estimator, X_train_all, y_train_all, budget, kf, eval_metric, best_val_loss, cv_score_agg_func, log_training_metric, fit_kwargs, free_mem_ratio)
#     782         groups_val = None
#     784 estimator.cleanup()
# --> 785 val_loss_i, metric_i, train_time_i, pred_time_i = get_val_loss(
#     786     config,
#     787     estimator,
#     788     X_train,
#     789     y_train,
#     790     X_val,
#     791     y_val,
#     792     weight_val,
#     793     groups_val,
#     794     eval_metric,
#     795     self,
#     796     labels,
#     797     budget_per_train,
#     798     log_training_metric=log_training_metric,
#     799     fit_kwargs=fit_kwargs,
#     800     free_mem_ratio=free_mem_ratio,
#     801 )
#     802 if isinstance(metric_i, dict) and "intermediate_results" in metric_i.keys():
#     803     del metric_i["intermediate_results"]
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\ml.py:516, in get_val_loss(config, estimator, X_train, y_train, X_val, y_val, weight_val, groups_val, eval_metric, task, labels, budget, log_training_metric, fit_kwargs, free_mem_ratio)
#     511 start = time.time()
#     512 # if groups_val is not None:
#     513 #     fit_kwargs['groups_val'] = groups_val
#     514 #     fit_kwargs['X_val'] = X_val
#     515 #     fit_kwargs['y_val'] = y_val
# --> 516 estimator.fit(X_train, y_train, budget=budget, free_mem_ratio=free_mem_ratio, **fit_kwargs)
#     517 val_loss, metric_for_logging, pred_time, _ = _eval_estimator(
#     518     config,
#     519     estimator,
#    (...)
#     530     fit_kwargs,
#     531 )
#     532 if hasattr(estimator, "intermediate_results"):
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\model.py:1592, in LGBMEstimator.fit(self, X_train, y_train, budget, free_mem_ratio, **kwargs)
#    1590     self._model.set_params(callbacks=callbacks[:-1])
#    1591 else:
# -> 1592     self._fit(X_train, y_train, callbacks=callbacks, **kwargs)
#    1593 best_iteration = (
#    1594     getattr(self._model.get_booster(), "best_iteration", None)
#    1595     if isinstance(self, XGBoostSklearnEstimator)
#    1596     else self._model.best_iteration_
#    1597 )
#    1598 if best_iteration is not None and best_iteration > 0:
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\model.py:236, in BaseEstimator._fit(self, X_train, y_train, **kwargs)
#     228         # groups_val = kwargs.get('groups_val')
#     229         # if groups_val is not None:
#     230         #     kwargs['eval_group'] = [group_counts(groups_val)]
#    (...)
#     233         #     kwargs['verbose'] = False
#     234         #     del kwargs['groups_val'], kwargs['X_val'], kwargs['y_val']
#     235 X_train = self._preprocess(X_train)
# --> 236 model = self.estimator_class(**self.params)
#     237 if logger.level == logging.DEBUG:
#     238     # xgboost 1.6 doesn't display all the params in the model str
#     239     logger.debug(f"flaml.automl.model - {model} fit started with params {self.params}")
#
# TypeError: 'NoneType' object is not callable

# %%
df.loc[df.TotalTime.isna(), 'TotalTime'] = y_pred
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df.loc[df.TotalTime.isna(), 'TotalTime'] = y_pred
#       2 df.info()
#
# NameError: name 'y_pred' is not defined

# %%
automl_clf = AutoML()
x_train, x_test = df.dropna(subset=['Toll']), df[df.Toll.isna()]
y_train = df[~df.Toll.isna()].Toll
automl_clf.fit(x_train, y_train, task="classification", verbose=False)
y_pred = automl_clf.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       2 x_train, x_test = df.dropna(subset=['Toll']), df[df.Toll.isna()]
#       3 y_train = df[~df.Toll.isna()].Toll
# ----> 4 automl_clf.fit(x_train, y_train, task="classification", verbose=False)
#       5 y_pred = automl_clf.predict(x_test)
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\automl.py:1983, in AutoML.fit(self, X_train, y_train, dataframe, label, metric, task, n_jobs, log_file_name, estimator_list, time_budget, max_iter, sample, ensemble, eval_method, log_type, model_history, split_ratio, n_splits, log_training_metric, mem_thres, pred_time_limit, train_time_limit, X_val, y_val, sample_weight_val, groups_val, groups, verbose, retrain_full, split_type, learner_selector, hpo_method, starting_points, seed, n_concurrent_trials, keep_search_state, preserve_checkpoint, early_stop, force_cancel, append_log, auto_augment, min_sample_size, use_ray, use_spark, free_mem_ratio, metric_constraints, custom_hp, time_col, cv_score_agg_func, skip_transform, mlflow_logging, fit_kwargs_by_estimator, mlflow_exp_name, **fit_kwargs)
#    1981 else:
#    1982     self._training_log = None
# -> 1983     self._search()
#    1984 if self._best_estimator:
#    1985     logger.info("fit succeeded")
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\automl.py:2533, in AutoML._search(self)
#    2531     state.best_config = state.init_config[0] if state.init_config else {}
#    2532 elif self._use_ray is False and self._use_spark is False:
# -> 2533     self._search_sequential()
#    2534 else:
#    2535     self._search_parallel()
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\automl.py:2358, in AutoML._search_sequential(self)
#    2352         search_state.search_alg.searcher.set_search_properties(
#    2353             metric=None,
#    2354             mode=None,
#    2355             metric_target=self._state.best_loss,
#    2356         )
#    2357 start_run_time = time.time()
# -> 2358 analysis = tune.run(
#    2359     search_state.training_function,
#    2360     search_alg=search_state.search_alg,
#    2361     time_budget_s=time_budget_s,
#    2362     verbose=max(self.verbose - 3, 0),
#    2363     use_ray=False,
#    2364     use_spark=False,
#    2365     force_cancel=self._force_cancel,
#    2366     mlflow_exp_name=self._mlflow_exp_name,
#    2367     automl_info=(0,),  # pass automl info to tune.run
#    2368     extra_tag=self.autolog_extra_tag,
#    2369 )
#    2370 time_used = time.time() - start_run_time
#    2371 better = False
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\tune\tune.py:887, in run(evaluation_function, config, low_cost_partial_config, cat_hp_cost, metric, mode, time_budget_s, points_to_evaluate, evaluated_rewards, resource_attr, min_resource, max_resource, reduction_factor, scheduler, search_alg, verbose, local_dir, num_samples, resources_per_trial, config_constraints, metric_constraints, max_failure, use_ray, use_spark, use_incumbent_result_in_evaluation, log_file_name, lexico_objectives, force_cancel, n_concurrent_trials, mlflow_exp_name, automl_info, extra_tag, cost_attr, cost_budget, **ray_args)
#     885 result = None
#     886 with PySparkOvertimeMonitor(time_start, time_budget_s, force_cancel):
# --> 887     result = evaluation_function(trial_to_run.config)
#     888 logger.debug(f"result in tune: {trial_to_run}, {result}")
#     889 if result is not None:
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\state.py:306, in AutoMLState._compute_with_config_base(config_w_resource, state, estimator, is_report)
#     289     del config["FLAML_sample_size"]
#     290 budget = (
#     291     None
#     292     if state.time_budget < 0
#    (...)
#     297     )
#     298 )
#     300 (
#     301     trained_estimator,
#     302     val_loss,
#     303     metric_for_logging,
#     304     _,
#     305     pred_time,
# --> 306 ) = compute_estimator(
#     307     sampled_X_train,
#     308     sampled_y_train,
#     309     state.X_val,
#     310     state.y_val,
#     311     state.weight_val,
#     312     state.groups_val,
#     313     state.train_time_limit if budget is None else min(budget, state.train_time_limit or np.inf),
#     314     state.kf,
#     315     config,
#     316     state.task,
#     317     estimator,
#     318     state.eval_method,
#     319     state.metric,
#     320     state.best_loss,
#     321     state.n_jobs,
#     322     state.learner_classes.get(estimator),
#     323     state.cv_score_agg_func,
#     324     state.log_training_metric,
#     325     this_estimator_kwargs,
#     326     state.free_mem_ratio,
#     327 )
#     328 if state.retrain_final and not state.model_history:
#     329     trained_estimator.cleanup()
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\ml.py:382, in compute_estimator(X_train, y_train, X_val, y_val, weight_val, groups_val, budget, kf, config_dic, task, estimator_name, eval_method, eval_metric, best_val_loss, n_jobs, estimator_class, cv_score_agg_func, log_training_metric, fit_kwargs, free_mem_ratio)
#     364     val_loss, metric_for_logging, train_time, pred_time = get_val_loss(
#     365         config_dic,
#     366         estimator,
#    (...)
#     379         free_mem_ratio=0,
#     380     )
#     381 else:
# --> 382     val_loss, metric_for_logging, train_time, pred_time = task.evaluate_model_CV(
#     383         config_dic,
#     384         estimator,
#     385         X_train,
#     386         y_train,
#     387         budget,
#     388         kf,
#     389         eval_metric,
#     390         best_val_loss,
#     391         cv_score_agg_func,
#     392         log_training_metric=log_training_metric,
#     393         fit_kwargs=fit_kwargs,
#     394         free_mem_ratio=0,
#     395     )
#     397 if isinstance(estimator, TransformersEstimator):
#     398     del fit_kwargs["metric"], fit_kwargs["X_val"], fit_kwargs["y_val"]
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\task\generic_task.py:785, in GenericTask.evaluate_model_CV(self, config, estimator, X_train_all, y_train_all, budget, kf, eval_metric, best_val_loss, cv_score_agg_func, log_training_metric, fit_kwargs, free_mem_ratio)
#     782         groups_val = None
#     784 estimator.cleanup()
# --> 785 val_loss_i, metric_i, train_time_i, pred_time_i = get_val_loss(
#     786     config,
#     787     estimator,
#     788     X_train,
#     789     y_train,
#     790     X_val,
#     791     y_val,
#     792     weight_val,
#     793     groups_val,
#     794     eval_metric,
#     795     self,
#     796     labels,
#     797     budget_per_train,
#     798     log_training_metric=log_training_metric,
#     799     fit_kwargs=fit_kwargs,
#     800     free_mem_ratio=free_mem_ratio,
#     801 )
#     802 if isinstance(metric_i, dict) and "intermediate_results" in metric_i.keys():
#     803     del metric_i["intermediate_results"]
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\ml.py:516, in get_val_loss(config, estimator, X_train, y_train, X_val, y_val, weight_val, groups_val, eval_metric, task, labels, budget, log_training_metric, fit_kwargs, free_mem_ratio)
#     511 start = time.time()
#     512 # if groups_val is not None:
#     513 #     fit_kwargs['groups_val'] = groups_val
#     514 #     fit_kwargs['X_val'] = X_val
#     515 #     fit_kwargs['y_val'] = y_val
# --> 516 estimator.fit(X_train, y_train, budget=budget, free_mem_ratio=free_mem_ratio, **fit_kwargs)
#     517 val_loss, metric_for_logging, pred_time, _ = _eval_estimator(
#     518     config,
#     519     estimator,
#    (...)
#     530     fit_kwargs,
#     531 )
#     532 if hasattr(estimator, "intermediate_results"):
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\model.py:1592, in LGBMEstimator.fit(self, X_train, y_train, budget, free_mem_ratio, **kwargs)
#    1590     self._model.set_params(callbacks=callbacks[:-1])
#    1591 else:
# -> 1592     self._fit(X_train, y_train, callbacks=callbacks, **kwargs)
#    1593 best_iteration = (
#    1594     getattr(self._model.get_booster(), "best_iteration", None)
#    1595     if isinstance(self, XGBoostSklearnEstimator)
#    1596     else self._model.best_iteration_
#    1597 )
#    1598 if best_iteration is not None and best_iteration > 0:
#
# File ~\Documents\GitHub\MachineLearning\myvenv\Lib\site-packages\flaml\automl\model.py:236, in BaseEstimator._fit(self, X_train, y_train, **kwargs)
#     228         # groups_val = kwargs.get('groups_val')
#     229         # if groups_val is not None:
#     230         #     kwargs['eval_group'] = [group_counts(groups_val)]
#    (...)
#     233         #     kwargs['verbose'] = False
#     234         #     del kwargs['groups_val'], kwargs['X_val'], kwargs['y_val']
#     235 X_train = self._preprocess(X_train)
# --> 236 model = self.estimator_class(**self.params)
#     237 if logger.level == logging.DEBUG:
#     238     # xgboost 1.6 doesn't display all the params in the model str
#     239     logger.debug(f"flaml.automl.model - {model} fit started with params {self.params}")
#
# TypeError: 'NoneType' object is not callable

# %%
df.loc[df.Toll.isna(), 'Toll'] = y_pred
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.loc[df.Toll.isna(), 'Toll'] = y_pred
#       2 df.info()
#
# NameError: name 'y_pred' is not defined

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# حال در این قسمت کار با داده‌های گم‌شده به اتمام رسید. مرحله بعدی کار با داده‌های پرت می‌باشد. برای شناسایی داده‌های پرت ابتدا با boxplot، نمودارهای ستون های numerical را رسم میکنیم.
#     </font>
# </p>

# %%
fig, ax = plt.subplots(4, 2, figsize=(20, 15))
sns.boxplot(x=df.Distance, ax = ax[0,0])
sns.boxplot(x=df.MaxSpeed, ax = ax[0,1])
sns.boxplot(x=df.AvgSpeed, ax = ax[1,0])
sns.boxplot(x=df.AvgMovingSpeed, ax = ax[1,1])
sns.boxplot(x=df.FuelEconomy, ax = ax[2,0])
sns.boxplot(x=df.TotalTime, ax = ax[2,1])
sns.boxplot(x=df.MovingTime, ax = ax[3,0])
# Out:
# <Axes: xlabel='MovingTime'>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# همانطور که در نمودار جعبه‌ای MaxSpeed مشاهده می‌شود، داده‌های پرت زیادی در این ستون وجود دارد (حتی داده‌منفی برای سرعت!). بنابراین باید این داده‌هارا شناسایی و حذف کرد.
# </ br>
# در قسمت پایین با استفاده از چارک‌ها و محاسبه IQR، داده‌های پرت ستون MaxSpeed را شناسایی کرده و به شکل سورت شده در لیست outlier_speed بریزید و مقادیر پرت ستون MaxSpeed  را با میانگین این ستون با دو رقم اعشار با استفاده از تابع round جایگزین کنید . (توجه کنید داده‌های پرت این ستون، نباید تاثیری بر میانگین بگذارند و بدون درنظر گرفتن آن‌ها باید میانگین محاسبه شود.)
# </font>
# </p>

# %%
Q1 = df['MaxSpeed'].quantile(0.25)
Q3 = df['MaxSpeed'].quantile(0.75)
IQR= (Q3 - Q1)
outlier_speed = df[(df['MaxSpeed'].values < Q1-1.5*IQR) | (df['MaxSpeed'].values > Q3+1.5*IQR)]
outlier_speed = outlier_speed['MaxSpeed'].tolist()
outlier_speed = sorted(outlier_speed)
outlier_speed
# Out:
# [-138.0, -120.0, -32.5, 112.2, 1205.0, 1207.4, 1207.5, 1263.7, 1328.5, 3123.7]

# %%
temp = df[~((df.MaxSpeed > Q3 + 1.5 * IQR) | (df.MaxSpeed < Q1 - 1.5 * IQR))].copy()

max_speed_mean = round(temp['MaxSpeed'].mean(), ndigits=2)
df.loc[((df.MaxSpeed > Q3 + 1.5 * IQR) | (df.MaxSpeed < Q1 - 1.5 * IQR)),'MaxSpeed'] = max_speed_mean

# %%
df
# Out:
#           Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0     1/6/2012     16:37     Friday    home     51.29    127.40      78.3
# 1     1/6/2012      8:20     Friday    work     51.63    130.30      81.8
# 2     1/4/2012     16:17  Wednesday    home     51.27    127.62      82.0
# 3     1/4/2012      7:53  Wednesday    work     49.17    132.30      74.2
# 4     1/3/2012     18:57    Tuesday    home     51.15    136.20      83.4
# ..         ...       ...        ...     ...       ...       ...       ...
# 200  7/18/2011      8:09     Monday    work     54.52    125.60      49.9
# 201  7/14/2011      8:03   Thursday    work     50.90    127.62      76.2
# 202  7/13/2011     17:08  Wednesday    home     51.96    132.60      57.5
# 203  7/12/2011     17:51    Tuesday    home     53.28    125.80      61.6
# 204  7/11/2011     16:56     Monday    home     51.73    127.62      62.8
#
#      AvgMovingSpeed  FuelEconomy  TotalTime  MovingTime Toll
# 0             84.80         8.69       39.3        36.3   No
# 1             88.90         8.69       37.9        34.9   No
# 2             81.83         8.69        NaN        35.9   No
# 3             82.90         8.69       39.8        35.6  NaN
# 4             88.10         8.69       36.8        34.8  NaN
# ..              ...          ...        ...         ...  ...
# 200           82.40         7.89       65.5        39.7   No
# 201           81.83         7.89       40.1        32.1  Yes
# 202           76.70         8.69       54.2        40.6  Yes
# 203           81.83         8.69       51.9        36.5  Yes
# 204           81.83         8.69        NaN        33.6  Yes
#
# [205 rows x 12 columns]

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# هم‌اکنون دوباره نمودار جعبه‌ای ستون MaxSpeed را رسم می‌کنیم. اگر مرحله بالا به درستی انجام شده‌باشد، باید شاهد تغییر در نمودار جعبه‌ای این ستون باشیم.
# </font>
# </p>

# %%
fig, ax = plt.subplots(figsize=(10, 4))
sns.boxplot(x=df.MaxSpeed)
# Out:
# <Axes: xlabel='MaxSpeed'>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>

# %%
import zlib
import zipfile


def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

np.savez("answers.npz", outlier_speed= outlier_speed)
df.to_csv('preprocessed_df.csv',index = True)

file_names = ["answers.npz", "preprocessed_df.csv", "correct_routing.ipynb"]
compress(file_names)
# Out:
# File Paths:
# ['answers.npz', 'preprocessed_df.csv', 'correct_routing.ipynb']
